# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/MyDrive/yolo_data/yolo with images" .
# Out:
# cp: cannot stat '/content/drive/MyDrive/yolo_data/yolo with images': No such file or directory

# %%
# !ls '/content/drive/MyDrive/oISgold/yolo with images' | head
# Out:
# classes.txt
# dataset_split
# dataset.yaml
# images
# labels
# notes.json
# split_dataset.py

# %%
# !pip install ultralytics --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 59.5 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# Загружаем предобученную модель
model = YOLO('yolov8n.pt')

# Запускаем обучение
model.train(
    data='/content/drive/MyDrive/oISgold/yolo_images/dataset.yaml',
    epochs=50,
    imgsz=640,
    batch=8,
    name='yolo_jewelry_model'
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls "/content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/train" | head
# !ls "/content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val" | head
# Out:
# 004225aa-1734204TSmvmDagWT2.jpg
# 00c25f7b-2125721Rh8CAkq5FBY_1.jpg
# 01112a9a-1934059x1iMGI2gqZE.jpg
# 0117343a-1727519n8KxPHBjWat.jpg
# 0148f4d6-1533818ywYTlbIhoFQ.jpg
# 01bbfbd2-1576896A4BlVZIy08G.jpg
# 01d39cf0-1796489qI9uDNmkNoV.jpg
# 025224e3-1282932StzoPeChEO3.jpg
# 026a5423-1378224esBH6EDsbZb.jpg
# 027abcbf-158443vOHJGJHo0Myh.jpg
# 021e2301-1323900Q1tMO5QhQo8.jpg
# 03a2f5c2-2913_serebryanyi_braslet_s_bukvoi_b_frontalnoe_1x.jpg
# 04a684ab-1322552A2XslbFGegO.jpg
# 053d53ee-1974002RkVUSSzlOJU.jpg
# 081afdf3-1283270Apj7pIliKS9.jpg
# 0aac17ae-2074780C5B3eEgCCD1.jpg
# 0b496d36-71894_braslet_iz_agata_i_serogo_obsidiana_foto_na_modeli_2x.jpg
# 0beabfeb-1473412IohiPoNoO4t.jpg
# 0f4d1ae3-1717159LeGXfYIH9XR.jpg
# 0f512534-2131607OnBt7EpcHsc.jpg

# %%
# !cat /content/drive/MyDrive/oISgold/yolo_images/dataset.yaml
# Out:
# path: /content/drive/MyDrive/oISgold/yolo_images/dataset_split
# train: images/train
# val: images/val
#
# names:
#   0: Beads
#   1: Bracelet
#   2: Brooch
#   3: Chain
#   4: Earrings
#   5: Hairpins
#   6: Jewelry with chain
#   7: Necklace
#   8: Pendant
#   9: Piercing
#   10: Ring

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="/content/drive/MyDrive/oISgold/yolo_images/dataset.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    name="jewelry_model"
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
yaml_path = "/content/drive/MyDrive/oISgold/yolo_images/dataset.yaml"

yaml_lines = [
    "path: /content/drive/MyDrive/oISgold/yolo_images/dataset_split",
    "train: images/train",
    "val: images/val",
    "",
    "names:",
    "  0: Beads",
    "  1: Bracelet",
    "  2: Brooch",
    "  3: Chain",
    "  4: Earrings",
    "  5: Hairpins",
    "  6: Jewelry with chain",
    "  7: Necklace",
    "  8: Pendant",
    "  9: Piercing",
    "  10: Ring"
]

with open(yaml_path, "w") as f:
    f.write("\n".join(yaml_lines))

# %%
import torch
print(torch.cuda.is_available())  # должно вывести True
print(torch.cuda.get_device_name(0))  # название GPU
# Out:
# True
# Tesla T4

# %%
# !pip install ultralytics --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.1 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/drive/MyDrive/oISgold/yolo_images/dataset.yaml",
    epochs=50,
    imgsz=640,
    batch=16,  # можно увеличить, если памяти хватит
    device=0,  # указывает использовать GPU 0
    name="jewelry_model_gpu"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 365MB/s]
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/jewelry_model_gpu/results.png')

# %%
results = model.predict("/content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val", save=True, conf=0.25)
# Out:
# image 1/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/021e2301-1323900Q1tMO5QhQo8.jpg: 640x640 1 Bracelet, 8.2ms
# image 2/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/03a2f5c2-2913_serebryanyi_braslet_s_bukvoi_b_frontalnoe_1x.jpg: 640x640 (no detections), 11.3ms
# image 3/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/04a684ab-1322552A2XslbFGegO.jpg: 640x640 1 Bracelet, 43.9ms
# image 4/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/053d53ee-1974002RkVUSSzlOJU.jpg: 640x640 1 Bracelet, 10.1ms
# image 5/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/081afdf3-1283270Apj7pIliKS9.jpg: 640x640 1 Bracelet, 9.8ms
# image 6/247 /content/drive/MyDrive/oISgold/yolo_images/dataset_split/images/val/0aac17ae-2074780C5B3eEgCCD1.jpg: 640x640 1 Bracelet, 1 Ring, 10.3ms
# ...

# %%
metrics = model.val()  # или model.val(data=...)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.6±0.4 ms, read: 54.0±44.5 MB/s, size: 165.9 KB)
# val: Scanning /content/drive/MyDrive/oISgold/yolo_images/dataset_split/labels/val.cache... 247 images, 0 backgrounds, 0 corrupt: 100%|██████████| 247/247 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:05<00:00,  2.77it/s]
#                    all        247        377      0.778      0.505      0.705      0.538
#                  Beads          5         10      0.737        0.1      0.145     0.0562
#               Bracelet        238        273      0.797      0.817      0.873      0.734
#                 Brooch          1          1          1          0      0.995      0.697
#     Jewelry with chain         66         71      0.634      0.704      0.744      0.621
# ...

# %%
import shutil
shutil.make_archive("/content/jewelry_model_gpu", 'zip', "runs/detect/jewelry_model_gpu")
# Out:
# '/content/jewelry_model_gpu.zip'

# %%
shutil.copy("/content/jewelry_model_gpu.zip", "/content/drive/MyDrive/oISgold")
# Out:
# '/content/drive/MyDrive/oISgold/jewelry_model_gpu.zip'
